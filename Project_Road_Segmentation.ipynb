# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash-Ram/Drivable-Area-Segmentation/blob/main/Project_Road_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Cloning our github repository**

# %%
# !git clone https://github.com/Akash-Ram/Drivable-Area-Segmentation.git
# %cd Drivable-Area-Segmentation
# Out:
# Cloning into 'Drivable-Area-Segmentation'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 51 (delta 18), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (51/51), done.
# /content/Drivable-Area-Segmentation

# %% [markdown]
# **Installing the requirements**

# %%
# !pip install tensorflow==1.13.1
# !pip install scipy==1.2.2
# Out:
# ...
#      |████████████████████████████████| 92.6 MB 29 kB/s
# ...
#      |████████████████████████████████| 367 kB 46.4 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 37.2 MB/s
# ...
#      |████████████████████████████████| 50 kB 5.7 MB/s
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.6.0
#     Uninstalling tensorflow-estimator-2.6.0:
#       Successfully uninstalled tensorflow-estimator-2.6.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.6.0
#     Uninstalling tensorboard-2.6.0:
#       Successfully uninstalled tensorboard-2.6.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.6.0
#     Uninstalling tensorflow-2.6.0:
#       Successfully uninstalled tensorflow-2.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %% [markdown]
# **Downloading the dataset and extracting it in the required location**

# %%
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_road.zip
# !unzip -q data_road.zip -d data
# Out:
# --2021-09-30 12:09:17--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_road.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.75.195
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.75.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 470992343 (449M) [application/zip]
# Saving to: ‘data_road.zip’
#
# data_road.zip       100%[===================>] 449.17M  27.6MB/s    in 18s
#
# 2021-09-30 12:09:36 (25.4 MB/s) - ‘data_road.zip’ saved [470992343/470992343]

# %% [markdown]
# **Running the main.py file and giving the required parameters.** During this execution we had used 10 epochs, but 20 epochs is recommended.

# %%
# !python main.py -i './data/data_road/training/image_2/*.png' -l './data/data_road/training/gt_image_2/*_road_*.png' -e 20 -n 2
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# **Displaying the segmented images that had been saved in "runs" folder.**

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

image_folder = '1632911478'

image = mpimg.imread('./runs/{}/um_000032.png'.format(image_folder))
plt.rcParams["figure.figsize"] = (20,10)
plt.imshow(image)
plt.show()
